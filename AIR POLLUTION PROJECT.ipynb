# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


df = pd.read_csv('death-rates-from-air-pollution.csv') #reads the csv file
df
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df.head() #shows the the country with the highest five death from the case studies.
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0  Afghanistan  AFG  1990                                  299.477309
# 1  Afghanistan  AFG  1991                                  291.277967
# 2  Afghanistan  AFG  1992                                  278.963056
# 3  Afghanistan  AFG  1993                                  278.790815
# 4  Afghanistan  AFG  1994                                  287.162923
#
#    Indoor air pollution (deaths per 100,000)  \
# 0                                 250.362910
# 1                                 242.575125
# 2                                 232.043878
# 3                                 231.648134
# 4                                 238.837177
#
#    Outdoor particulate matter (deaths per 100,000)  \
# 0                                        46.446589
# 1                                        46.033841
# 2                                        44.243766
# 3                                        44.440148
# ...

# %%
df.tail() #shows the the country with the lowest five death from the case studies.
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 6463  Zimbabwe  ZWE  2013                                  143.850145
# 6464  Zimbabwe  ZWE  2014                                  138.200536
# 6465  Zimbabwe  ZWE  2015                                  132.752553
# 6466  Zimbabwe  ZWE  2016                                  128.692138
# 6467  Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# 6463                                 113.456097
# 6464                                 108.703566
# 6465                                 104.340506
# 6466                                 100.392287
# 6467                                  96.235996
#
#       Outdoor particulate matter (deaths per 100,000)  \
# 6463                                        27.589603
# 6464                                        26.760618
# 6465                                        25.715415
# ...

# %%
df.describe() # gives brief insight of the case studies
# Out:
#               Year  Air pollution (total) (deaths per 100,000)  \
# count  6468.000000                                 6468.000000
# mean   2003.500000                                   87.804083
# std       8.078372                                   57.845436
# min    1990.000000                                    8.401696
# 25%    1996.750000                                   41.016114
# 50%    2003.500000                                   72.653557
# 75%    2010.250000                                  127.607177
# max    2017.000000                                  318.463253
#
#        Indoor air pollution (deaths per 100,000)  \
# count                                6468.000000
# mean                                   50.481504
# std                                    58.722565
# min                                     0.003859
# 25%                                     2.002779
# 50%                                    23.737851
# ...

# %%
df.mean() # gives average of cases of air polution under study.
# Out:
# Year                                               2003.500000
# Air pollution (total) (deaths per 100,000)           87.804083
# Indoor air pollution (deaths per 100,000)            50.481504
# Outdoor particulate matter (deaths per 100,000)      35.114982
# Outdoor ozone pollution (deaths per 100,000)          3.370793
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = sns.lineplot(x="Year", y="Air pollution (total) (deaths per 100,000)", data=df)
fig = sns.lineplot(x="Year", y="Indoor air pollution (deaths per 100,000)", data=df)
fig = sns.lineplot(x="Year", y="Outdoor particulate matter (deaths per 100,000)", data=df)
fig = sns.lineplot(x="Year", y="Outdoor ozone pollution (deaths per 100,000)", data=df)

plt.title # shows World wide death rates from air pollution.
plt.show()

# %%
entity_df = df.groupby('Code').mean().sort_values('Air pollution (total) (deaths per 100,000)', ascending=False)
entity_df['Code'] = entity_df.index
entity_df
# Out:
#         Year  Air pollution (total) (deaths per 100,000)  \
# Code
# PNG   2003.5                                  285.494328
# AFG   2003.5                                  252.842551
# CAF   2003.5                                  223.826758
# SLB   2003.5                                  218.664031
# SOM   2003.5                                  211.662481
# ...      ...                                         ...
# JPN   2003.5                                   17.182493
# FIN   2003.5                                   16.630969
# ISL   2003.5                                   16.506321
# NZL   2003.5                                   15.925364
# SWE   2003.5                                   15.728593
#
#       Indoor air pollution (deaths per 100,000)  \
# Code
# PNG                                  258.717975
# AFG                                  203.967377
# CAF                                  181.785495
# SLB                                  199.800174
# ...

# %%
sns.barplot(x="Code", y="Air pollution (total) (deaths per 100,000)", data=entity_df.head(10))
plt.title("Country ranking")
plt.show() #gives details of country ranking according to volume of air pollution.

# %% [markdown]
# Conclusion
# Outdoor Ozone contributes low to pollution compared to indoor air polllution and outdoor particulate matter in most of the countries considered.
